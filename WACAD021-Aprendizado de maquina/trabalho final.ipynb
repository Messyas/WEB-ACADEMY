# %% [markdown]
# # Proposta de Projeto: Análise Exploratória e Visualização de Focos de Queimadas no Brasil
#
# ---
#
# ## Seção 1: Introdução e Objetivos do Projeto
#
# ### 1.1. Contextualização: A Importância do Monitoramento Ambiental no Brasil
#
# O Brasil, detentor de uma das maiores biodiversidades do planeta, enfrenta desafios ambientais significativos, com as queimadas e o desmatamento figurando entre as principais ameaças aos seus biomas, especialmente a Amazônia, o Cerrado e o Pantanal. O monitoramento desses fenômenos é crucial não apenas para a conservação ambiental, mas também para a saúde pública, a economia e o cumprimento de metas climáticas internacionais. A análise de dados sobre a ocorrência de fogo na vegetação permite identificar padrões, avaliar a eficácia de políticas públicas e direcionar ações de fiscalização e combate.
#
# Nesse contexto, a política de dados abertos adotada por instituições governamentais é um pilar para a transparência e o controle social. A disponibilização de informações de qualidade permite que pesquisadores, jornalistas e a sociedade civil organizada contribuam para o combate a crimes ambientais, promovendo soluções inovadoras e de baixo custo. Este projeto se insere nesse esforço coletivo, utilizando dados públicos para gerar conhecimento e ferramentas de visualização sobre um tema de alta relevância nacional.
#
# ### 1.2. O Conjunto de Dados: Focos de Queimadas do INPE
#
# A fonte de dados para este projeto é o **Programa Queimadas** do Instituto Nacional de Pesquisas Espaciais (INPE), uma referência global no monitoramento de queimadas e incêndios florestais por meio de imagens de satélite. O INPE disponibiliza um vasto acervo de dados abertos, atualizados continuamente, que são essenciais para a pesquisa científica e a gestão ambiental no país.
#
# Para este trabalho, você utilizará os dados anuais de focos de queimadas do ano de 2024, disponíveis para download no formato CSV.
#
# **Link para download:** `https://dataserver-coids.inpe.br/queimadas/queimadas/focos/csv/anual/Brasil_todos_sats/focos_br_todos-sats_2024.zip`
#
# ### 1.3. Desafio Proposto e Objetivos
#
# O seu objetivo é conduzir uma análise exploratória de dados (EDA) completa sobre os focos de queimadas detectados no Brasil durante o ano de 2024. Você deverá realizar todo o processo de ciência de dados, desde a obtenção e limpeza dos dados até a criação de visualizações e um dashboard interativo para apresentar seus resultados.
#
# Ao longo do projeto, você deverá responder a perguntas-chave como:
# * Qual a distribuição temporal (sazonalidade) dos focos de queimadas?
# * Quais estados e biomas são os mais afetados?
# * Onde se concentram geograficamente os focos de calor?
# * Quais municípios aparecem com maior frequência nos registros?
#
# É fundamental, antes de prosseguir, esclarecer uma nuance técnica dos dados. O dataset do INPE registra "focos de calor", que são anomalias térmicas na superfície terrestre detectadas por sensores de satélite. Embora um foco de calor seja um forte indicativo de queima de vegetação, ele não é, por definição, sinônimo de "incêndio florestal" ou "área queimada". Um foco pode ser originado por outras fontes, como atividades industriais ou agrícolas controladas. Portanto, sua análise deve se basear na ocorrência e distribuição desses pontos de anomalia térmica, que servem como um excelente *proxy* para a atividade de fogo no país. Leve essa distinção em conta na interpretação e comunicação dos seus resultados.
#
# ---
#
# ## Seção 2: Preparação do Ambiente e Carga dos Dados
#
# ### 2.1. Bibliotecas Recomendadas
#
# Para este projeto, recomenda-se o uso das seguintes bibliotecas Python: **pandas** para manipulação de dados, **matplotlib** e **seaborn** para visualização, **wordcloud** para a análise de texto e **streamlit** para a criação do dashboard. Certifique-se de que seu ambiente de desenvolvimento esteja com todas as dependências necessárias instaladas.
#
# ### 2.2. Carga dos Dados
#
# Sua primeira tarefa é carregar o arquivo CSV disponibilizado pelo INPE em um DataFrame do pandas. Após o carregamento, realize uma inspeção inicial para verificar se os dados foram importados corretamente.
#
# ---
#
# ## Seção 3: Limpeza e Pré-processamento dos Dados (Data Wrangling)
#
# ### 3.1. Análise Estrutural e Dicionário de Dados
#
# Antes de iniciar a limpeza, explore a estrutura do seu DataFrame.
# * Qual o número de linhas e colunas?
# * Quais são os nomes e os tipos de dados de cada coluna?
# * Existem dados ausentes ou registros duplicados? Qual a melhor estratégia para lidar com eles neste contexto? Justifique sua decisão.
#
# Utilize a tabela abaixo como referência para entender o significado de cada coluna.
#
# **Tabela 1: Dicionário de Dados**
#
# | Coluna | Descrição | Tipo de Dado |
# | :--- | :--- | :--- |
# | data_pas | Data e hora do registro do foco de calor. | object (string) |
# | satelite | Nome do satélite que detectou o foco. | object (string) |
# | pais | País onde o foco foi detectado. | object (string) |
# | estado | Estado da federação onde o foco foi detectado. | object (string) |
# | municipio | Município onde o foco foi detectado. | object (string) |
# | bioma | Bioma onde o foco foi detectado. | object (string) |
# | diasemchuva | Número de dias consecutivos sem chuva no local. | float64 |
# | precipitacao | Precipitação (chuva) acumulada (em mm) no dia. | float64 |
# | riscofogo | Risco de fogo calculado pelo INPE. | float64 |
# | latitude | Coordenada de latitude do foco (em graus decimais). | float64 |
# | longitude | Coordenada de longitude do foco (em graus decimais). | float64 |
# | frp | Fire Radiative Power, uma medida da energia liberada pelo fogo. | float64 |
#
# ### 3.2. Transformação de Dados e Engenharia de Features
#
# A coluna `data_pas` é crucial para a análise, mas seu formato original (texto) limita seu uso.
# * Que tipo de transformação é necessária para que você possa realizar análises temporais com esta coluna?
# * Após a transformação, crie novas colunas que extraiam informações úteis, como o **mês** e o **dia da semana** de cada registro. Essas novas *features* serão essenciais para as próximas etapas.
#
# ### 3.3. Análise Descritiva Inicial
#
# Gere um resumo estatístico para as colunas numéricas do DataFrame. O que os valores de média, desvio padrão, mínimo, máximo e os quartis revelam sobre variáveis como `riscofogo`, `diasemchuva` e `precipitacao`?
#
# ---
#
# ## Seção 4: Análise Exploratória e Visualização de Dados (EDA)
#
# Nesta seção, você deverá criar visualizações para responder às perguntas centrais do projeto. Lembre-se de dar títulos claros e rótulos adequados a todos os seus gráficos.
#
# ### 4.1. Análise Temporal
#
# Qual é a distribuição dos focos de queimadas ao longo do ano de 2024? Crie uma visualização (um gráfico de linhas é uma boa sugestão) que mostre a sazonalidade do fenômeno. Quais meses apresentam os maiores picos de ocorrências? A que você atribui esse padrão?
#
# ### 4.2. Análise Categórica
#
# Quais estados e biomas são mais afetados pelas queimadas?
# * Crie um gráfico de barras para apresentar os 10 estados com o maior número de focos de calor.
# * Crie um segundo gráfico de barras para mostrar a distribuição total de focos por bioma.
# * Apresente também uma tabela sumarizando os dados do top 10 estados para maior clareza.
#
# ### 4.3. Análise Geográfica
#
# Como os focos de calor se distribuem geograficamente pelo território brasileiro? Crie um gráfico de dispersão (*scatterplot*) utilizando as coordenadas de latitude e longitude para visualizar os "hotspots" de queimadas no país.
# * **Dica:** Plotar todos os pontos do dataset pode resultar em um gráfico muito denso e lento para renderizar. Considere utilizar uma amostra aleatória dos dados (e.g., 50.000 pontos) para esta visualização.
#
# ---
#
#
# ## Seção 5: Desenvolvimento de um Dashboard Interativo com Streamlit
#
# ### 5.1. O Desafio Final
#
# Como etapa final do projeto, seu desafio é consolidar suas análises em um dashboard interativo usando a biblioteca Streamlit. O objetivo é criar uma ferramenta que permita a um usuário explorar os dados de forma dinâmica. Salve seu código em um arquivo chamado `dashboard.py`.
#
# ### 5.2. Requisitos do Dashboard
#
# Seu dashboard deve conter, no mínimo, os seguintes elementos:
# 1.  **Título e Descrição:** Um título claro e um breve parágrafo explicando o propósito do dashboard e a fonte dos dados.
# 2.  **Filtro Interativo:** Uma barra lateral (*sidebar*) com um filtro *dropdown* que permita ao usuário selecionar um estado específico ou a opção "Todos os Estados".
# 3.  **Métricas Principais (KPIs):** Cartões que exibam números-chave, como o total de focos registrados na seleção atual e o bioma mais afetado. Esses valores devem ser atualizados dinamicamente com base no filtro de estado.
# 4.  **Mapa Geográfico:** Um mapa que mostre a distribuição dos focos de calor. O mapa deve ser atualizado para exibir apenas os focos do estado selecionado no filtro.
# 5.  **Gráfico Temporal:** Um gráfico (de barras ou de linhas) que mostre o número de focos por mês para a seleção do filtro.
# 6.  **Tabela de Dados:** Uma pequena tabela que exiba as primeiras linhas dos dados filtrados, mostrando colunas relevantes como `datahora`, `municipio` e `bioma`.
#
# ### 5.3. Como Executar o Dashboard
#
# Para visualizar o dashboard interativo, abra um terminal, navegue até o diretório onde você salvou o arquivo `dashboard.py` e execute o seguinte comando :
#
# ```bash
# streamlit run dashboard.py
# ```
#
# ---
#
# ## Seção 6: Conclusão e Entrega do Projeto
#
# ### 6.1. Relatório Final
#
# Ao final do seu notebook, inclua uma seção de conclusão contendo:
# * **Resumo dos Insights:** Um resumo dos principais padrões e descobertas que você extraiu da sua análise.
# * **Limitações do Estudo:** Uma discussão sobre as limitações da sua análise. Considere o escopo temporal (apenas um ano), a natureza dos dados ("focos de calor" vs. "área queimada") e a ausência de cruzamento com outras fontes de dados.
# * **Sugestões para Trabalhos Futuros:** Proponha pelo menos duas ideias para análises mais avançadas que poderiam ser construídas a partir deste projeto (ex: modelagem preditiva, análise de correlação com dados climáticos, etc.).
#
# ### 6.2. Critérios de Avaliação
#
# O projeto será avaliado com base na correção do código, na qualidade e clareza das visualizações de dados, na funcionalidade do dashboard interativo e na profundidade das suas conclusões e insights. Não esqueça que você deve entregar o notebook com preparação de dados e relatório, bem como o arquivo do dashboard
