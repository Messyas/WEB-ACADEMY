# %% [markdown]
# # Ciência de Dados para Desenvolvedores Web: Da Visualização à Análise de Texto
#
#
# ### Objetivo da Aula
# - **Visão Geral:** Conectar o mundo do desenvolvimento web com o universo da ciência de dados, indo além da simples manipulação de dados para a extração de insights valiosos.
# - **Persona:** Você é um desenvolvedor na Olist. A equipe de negócios precisa entender tendências de vendas, desempenho de produtos e o sentimento dos clientes. Sua tarefa é usar suas habilidades técnicas para responder a essas perguntas com dados.
#
# ### Nosso Estudo de Caso: O Dataset Olist
# - **Fonte:** Utilizaremos o **Brazilian E-Commerce Public Dataset by Olist**, um conjunto de dados real, rico e complexo.
# - **Relevância:** Ele espelha os tipos de dados que empresas geram diariamente, contendo desde dados estruturados de vendas até avaliações de clientes em texto livre.

# %%
# !pip install nltk

# %% [markdown]
# ## Configuração Inicial: Carregando e Preparando Nosso Universo de Dados
#
# ### 1. Entendendo o Esquema
# - **Contexto:** Assim como em sistemas do mundo real, os dados da Olist são normalizados e distribuídos em múltiplos arquivos. Nossa primeira tarefa é unificá-los.
# - **Mapa de Dados:**
#
# | Arquivo CSV                             | Colunas Relevantes                                                    | Descrição                                                              |
# | :-------------------------------------- | :-------------------------------------------------------------------- | :--------------------------------------------------------------------- |
# | `olist_customers_dataset.csv`           | `customer_id`, `customer_unique_id`, `customer_state`                 | Contém dados sobre os clientes e sua localização.                      |
# | `olist_orders_dataset.csv`              | `order_id`, `customer_id`, `order_status`, `order_purchase_timestamp` | Contém dados sobre os pedidos, como status e data da compra.           |
# | `olist_order_items_dataset.csv`         | `order_id`, `product_id`, `price`, `freight_value`                    | Detalha os itens dentro de cada pedido, incluindo preço e frete.         |
# | `olist_products_dataset.csv`            | `product_id`, `product_category_name`                                 | Contém informações sobre os produtos, como sua categoria.              |
# | `olist_order_reviews_dataset.csv`       | `order_id`, `review_score`, `review_comment_message`                  | Contém as avaliações (notas e comentários) feitas pelos clientes.      |
# | `product_category_name_translation.csv` | `product_category_name`, `product_category_name_english`              | Traduz os nomes das categorias de produtos para o inglês.              |

# %% [markdown]
# ### 2. Exercício Prático: Montando o DataFrame Principal
# - **Tarefa:** Carregar os arquivos CSV e uni-los em um único DataFrame analítico usando a biblioteca Pandas.

# %%
# Importando as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from collections import Counter

# Configurações iniciais para bibliotecas
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)
try:
    nltk.data.find('tokenizers/punkt')
    nltk.data.find('corpora/stopwords')
except LookupError:
    print("Baixando pacotes NLTK necessários...")
    nltk.download('punkt')
    nltk.download('stopwords')

# Carregando os datasets (assumindo que estão na mesma pasta do notebook)
try:
    customers = pd.read_csv('data/olist_customers_dataset.csv')
    orders = pd.read_csv('data/olist_orders_dataset.csv')
    order_items = pd.read_csv('data/olist_order_items_dataset.csv')
    products = pd.read_csv('data/olist_products_dataset.csv')
    reviews = pd.read_csv('data/olist_order_reviews_dataset.csv')
    translation = pd.read_csv('data/product_category_name_translation.csv')
    print("Datasets carregados com sucesso!")
except FileNotFoundError as e:
    print(f"Erro: Arquivo não encontrado. Verifique o nome e o caminho do arquivo: {e.filename}")

# Unindo (merging) os DataFrames
df = pd.merge(orders, order_items, on='order_id')
df = pd.merge(df, products, on='product_id')
df = pd.merge(df, customers, on='customer_id')
df = pd.merge(df, reviews, on='order_id')
df = pd.merge(df, translation, on='product_category_name')

# Convertendo colunas de data para o formato datetime
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])
df['order_delivered_customer_date'] = pd.to_datetime(df['order_delivered_customer_date'])
df['order_estimated_delivery_date'] = pd.to_datetime(df['order_estimated_delivery_date'])

print("\nDataFrame unificado criado.")
print("\nPrimeiras 5 linhas do DataFrame:")
display(df.head())

print("\nColunas resultantes:")
print(df.columns.tolist())
# Out:
# Baixando pacotes NLTK necessários...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Datasets carregados com sucesso!
#
# DataFrame unificado criado.
#
# Primeiras 5 linhas do DataFrame:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  order_item_id  \
# 0                    2017-10-18              1
# 1                    2018-08-13              1
# 2                    2018-09-04              1
# 3                    2017-12-15              1
# 4                    2018-02-26              1
#
#                          product_id  ... customer_zip_code_prefix  \
# 0  87285b34884572647811a353c7ac498a  ...                     3149
# 1  595fac2a385ac33a80bd5114aec74eb8  ...                    47813
# 2  aa4383b373c6aca5d8797843e5594415  ...                    75265
# 3  d0b61bfb1de832b15ba9d266ca96e5b0  ...                    59296
# 4  65266b2da20d04dbe00c5c2d3bb7859e  ...                     9195
#
#              customer_city  customer_state                         review_id  \
# 0                sao paulo              SP  a54f0611adc9ed256b57ede6b6eb5114
# 1                barreiras              BA  8d5266042046a06655c8db133d120ba5
# 2               vianopolis              GO  e73b67b67587f7644d5bd1a52deb1b01
# 3  sao goncalo do amarante              RN  359d03e676b3c069f62cadba8dd3f6e8
# 4              santo andre              SP  e50934924e227544ba8246aeb3770dd4
#
#   review_score  review_comment_title  \
# 0            4                   NaN
# 1            4      Muito boa a loja
# 2            5                   NaN
# 3            5                   NaN
# 4            5                   NaN
#
#                               review_comment_message  review_creation_date  \
# 0  Não testei o produto ainda, mas ele veio corre...   2017-10-11 00:00:00
# 1                               Muito bom o produto.   2018-08-08 00:00:00
# 2                                                NaN   2018-08-18 00:00:00
# 3  O produto foi exatamente o que eu esperava e e...   2017-12-03 00:00:00
# 4                                                NaN   2018-02-17 00:00:00
#
#    review_answer_timestamp  product_category_name_english
# 0      2017-10-12 03:43:48                     housewares
# 1      2018-08-08 18:37:50                      perfumery
# 2      2018-08-22 19:07:58                           auto
# 3      2017-12-05 19:21:58                       pet_shop
# 4      2018-02-18 13:02:51                     stationery
#
# [5 rows x 33 columns]
# Colunas resultantes:
# ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value', 'product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state', 'review_id', 'review_score', 'review_comment_title', 'review_comment_message', 'review_creation_date', 'review_answer_timestamp', 'product_category_name_english']

# %% [markdown]
# # Parte 1: O Poder da Narrativa Visual (Fundamentos da Visualização de Dados)

# %% [markdown]
# ### 1.1. Por que uma Imagem Vale Mais que Mil Linhas de Dados
#
# #### 1.1.1. Os Limites das Estatísticas Resumidas: O Quarteto de Anscombe
# - **Conceito:** Em 1973, o estatístico Francis Anscombe demonstrou que estatísticas descritivas quase idênticas podem esconder realidades drasticamente diferentes.
# - **Relevância para Desenvolvedores:** O mundo de um dev é construído sobre precisão (`2.000`, não "~2"). O quarteto desafia essa confiança na precisão numérica isolada, mostrando que a mesma média ($9.0$) e correlação ($0.816$) podem descrever quatro cenários distintos. Isso força uma reavaliação: o contexto e a distribuição são tão vitais quanto as métricas. A pergunta muda de "Qual é a média?" para "Como é a distribuição?".
# - **A Lição:** Confiar apenas em resumos numéricos é uma forma de cegueira intelectual; a visualização revela a verdade dos dados.

# %%
# Carregando o dataset de exemplo do Seaborn
anscombe = sns.load_dataset("anscombe")

# Calculando estatísticas descritivas para cada dataset do quarteto
stats = anscombe.groupby('dataset').agg(['mean', 'std', 'count'])
correlations = anscombe.groupby('dataset').corr().unstack().iloc[:, 1]

print("Estatísticas Descritivas:")
print(stats)
print("\nCorrelações (x, y):")
print(correlations)

# Visualizando o Quarteto de Anscombe
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=anscombe,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})
plt.suptitle("O Quarteto de Anscombe: Mesmas Estatísticas, Gráficos Diferentes", y=1.02)
plt.show()
# Out:
# Estatísticas Descritivas:
#            x                         y
#         mean       std count      mean       std count
# dataset
# I        9.0  3.316625    11  7.500909  2.031568    11
# II       9.0  3.316625    11  7.500909  2.031657    11
# III      9.0  3.316625    11  7.500000  2.030424    11
# IV       9.0  3.316625    11  7.500909  2.030579    11
#
# Correlações (x, y):
# dataset
# I      0.816421
# II     0.816237
# III    0.816287
# IV     0.816521
# Name: (x, y), dtype: float64

# %% [markdown]
# #### 1.1.2. Como Vemos os Dados: A Ciência da Percepção Visual
# - **Conceito:** A visualização de dados eficaz não é arte, mas uma ciência baseada em como nosso cérebro processa informações. É uma otimização para "ciclos cerebrais".
# - **Atributos Pré-atentivos:** São propriedades visuais que nosso cérebro processa em menos de 500ms, sem esforço consciente. Os mais importantes são:
#   - **Comprimento:** Ideal para comparações (base dos gráficos de barras).
#   - **Posição:** Processada rapidamente em eixos cartesianos (gráficos de dispersão).
#   - **Cor (Matiz e Intensidade):** Usada para agrupar itens ou indicar magnitude.
#   - **Tamanho:** Representa uma quantidade.
# - **Analogia para Desenvolvedores:** Usar um gráfico de barras (comprimento) descarrega a tarefa lenta de "pensar" sobre números (córtex cerebral) para a parte rápida e poderosa do cérebro que "vê" (córtex visual). A escolha do gráfico correto é uma otimização de desempenho para a interface homem-computador.

# %% [markdown]
# ### 1.2. Uma Linguagem Simples para Gráficos (A Gramática dos Gráficos)
#
# - **Conceito:** Em vez de memorizar dezenas de tipos de gráficos, podemos aprender uma "linguagem" ou um "padrão de design" para construir visualizações. Este conceito, conhecido como a **Gramática dos Gráficos**, descreve os componentes de um gráfico de forma estruturada.
# - **As 3 Camadas Essenciais:**
#   1.  **Dados (Data):** O DataFrame que contém as informações (nosso `df` unificado).
#   2.  **Estética (Aesthetics - `aes`):** O mapeamento das colunas dos dados para as propriedades visuais do gráfico (ex: `price` -> eixo Y, `product_category` -> cor).
#   3.  **Geometrias (Geometries - `geom`):** As formas visuais que representam os dados (pontos, linhas, barras).
# - **Mudança de Mentalidade:** A abordagem muda de "preciso de uma função para gráfico de dispersão" para "preciso representar meus dados com *pontos*, mapeando a variável A para X e a variável B para Y". É um modelo mental mais poderoso e extensível.

# %%
# Exemplo prático da Gramática dos Gráficos com Seaborn

# 1. Dados: Usaremos nosso DataFrame 'df'
# 2. Estética: Mapearemos 'price' para o eixo x e 'freight_value' para o eixo y
# 3. Geometria: Usaremos pontos (scatter)

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='price', y='freight_value') # Aqui definimos as 3 camadas
plt.title('Relação entre Preço e Valor do Frete')
plt.xlabel('Preço (R$)')
plt.ylabel('Valor do Frete (R$)')
# Limitando os eixos para melhor visualização, pois há outliers
plt.xlim(0, 2000)
plt.ylim(0, 200)
plt.show()

# %% [markdown]
# ### 1.3. O Kit de Ferramentas Essencial: Escolhendo o Gráfico Certo
#
# | Objetivo                                           | Gráfico Recomendado  |
# | :------------------------------------------------- | :------------------- |
# | Comparar valores entre diferentes categorias       | Gráfico de Barras    |
# | Mostrar uma tendência ou mudança ao longo do tempo   | Gráfico de Linhas    |
# | Entender a distribuição de frequência de um número | Histograma           |
# | Investigar a relação entre duas variáveis numéricas | Gráfico de Dispersão |
# | Comparar distribuições e encontrar outliers        | Box Plot             |

# %% [markdown]
# #### 1.3.1. Gráficos de Barras: Comparando Categorias
# - **Propósito:** Comparar um valor numérico entre categorias discretas. Nossos cérebros são excelentes em comparar comprimentos a partir de uma linha de base comum.
# - **Exemplo Olist:** Quais categorias de produtos têm o maior valor médio de frete?

# %%
# Calculando o valor médio do frete por categoria
avg_freight_by_category = df.groupby('product_category_name_english')['freight_value'].mean().sort_values(ascending=False).head(10)

# Criando o gráfico de barras
plt.figure(figsize=(12, 8))
sns.barplot(x=avg_freight_by_category.values, y=avg_freight_by_category.index, palette='viridis')
plt.title('Top 10 Categorias por Valor Médio de Frete')
plt.xlabel('Valor Médio do Frete (R$)')
plt.ylabel('Categoria do Produto')
plt.show()
#uma sugestao seria fazer um deep dyving
# Out:
# /tmp/ipython-input-3458675986.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_freight_by_category.values, y=avg_freight_by_category.index, palette='viridis')

# %% [markdown]
# - **Boas Práticas:**
#   - Sempre inicie o eixo de valor em zero para evitar comparações enganosas.
#   - Ordene as barras (maior para menor ou vice-versa) para facilitar a leitura.
# - **Exercício:** Gere um gráfico de barras **horizontal** mostrando o número total de pedidos para os 10 principais estados dos clientes. *Por que horizontal?* Porque os nomes dos estados podem ser longos e são mais fáceis de ler no eixo Y.

# %%
# Calculando o valor médio do frete por categoria
avg_freight_by_category = df.groupby('customer_state')['order_id'].nunique().sort_values(ascending=False).head(10) #cuidado pra nao repetir id, por isso nao foi feito com count

# Criando o gráfico de barras
plt.figure(figsize=(12, 8))
sns.barplot(x=avg_freight_by_category.values, y=avg_freight_by_category.index, palette='Spectral')
plt.title('Top 10 Estados por Número de Pedidos')
plt.xlabel('Número de pedidos')
plt.ylabel('Estados')
plt.show()
#uma sugestao seria fazer um deep dyving
# Out:
# /tmp/ipython-input-2554613820.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_freight_by_category.values, y=avg_freight_by_category.index, palette='Spectral')

# %% [markdown]
# #### 1.3.2. Gráficos de Linhas: Acompanhando Tendências ao Longo do Tempo
# - **Propósito:** Visualizar a tendência de uma variável contínua, geralmente ao longo do tempo. As linhas de conexão enfatizam a progressão e a taxa de mudança.
# - **Exemplo Olist:** Como as vendas da Olist evoluíram ao longo do tempo?

# %%
# Agrupando os pedidos por mês
df['order_month'] = df['order_purchase_timestamp'].dt.to_period('M')
monthly_orders = df.groupby('order_month')['order_id'].nunique()

# Convertendo o período para timestamp para plotagem
monthly_orders.index = monthly_orders.index.to_timestamp()

# Criando o gráfico de linhas
plt.figure(figsize=(14, 7))
sns.lineplot(x=monthly_orders.index, y=monthly_orders.values, marker='o')
plt.title('Número de Pedidos por Mês na Olist (2016-2018)')
plt.xlabel('Mês da Compra')
plt.ylabel('Número de Pedidos')
plt.show()

# %% [markdown]
# - **Boas Práticas:**
#   - Use para dados contínuos, não para categorias discretas sem ordem intrínseca.
#   - Certifique-se de que o eixo do tempo tenha intervalos regulares.
# - **Exercício:** Plote a **receita** mensal (soma de `price`) em um gráfico de linhas. A tendência da receita espelha a tendência do número de pedidos? O que poderia explicar eventuais diferenças?

# %%
# Agrupando os pedidos por mês
df['order_month'] = df['order_purchase_timestamp'].dt.to_period('M')
monthly_orders = df.groupby('order_month')['order_id'].nunique()

# Convertendo o período para timestamp para plotagem
monthly_orders.index = monthly_orders.index.to_timestamp()

# Criando o gráfico de linhas
plt.figure(figsize=(14, 7))
sns.lineplot(x=monthly_orders.index, y=monthly_orders.values, marker='o')
plt.title('Receita Mensal na Olist (2016-2018)')
plt.xlabel('Mês da Compra')
plt.ylabel('Receita (R$)')
plt.show()

# %% [markdown]
# #### 1.3.3. Histogramas: Entendendo Distribuições
# - **Propósito:** Entender a distribuição de frequência de uma única variável numérica contínua, agrupando os valores em "bins" ou intervalos. Ao contrário de um gráfico de barras, não há espaços entre as barras, significando um intervalo contínuo.
# - **Exemplo Olist:** Qual é a distribuição dos preços dos itens vendidos?

# %%
# Filtrando para uma faixa de preço mais comum para melhor visualização
prices_filtered = df[df['price'] < 500]['price']

# Criando o histograma
plt.figure(figsize=(10, 6))
sns.histplot(prices_filtered, bins=50, kde=True) # kde=True adiciona uma linha de estimativa de densidade
plt.title('Distribuição de Preços dos Produtos (abaixo de R$ 500)')
plt.xlabel('Preço (R$)')
plt.ylabel('Frequência (Contagem de Produtos)')
plt.show()

# %% [markdown]
# - **Boas Práticas:**
#   - A escolha da largura dos "bins" é crucial e pode alterar a história que o gráfico conta. Experimente com diferentes números de bins.
# - **Exercício:** Crie um histograma para a coluna `freight_value`. Filtre outliers extremos (ex: fretes > R$ 200) para obter uma visão melhor da distribuição principal. Qual é a faixa de frete mais comum?

# %%
# Filtrando para uma faixa de frete mais comum para melhor visualização
freight_filtered = df[df['freight_value'] < 200]['freight_value']

# Criando o histograma
plt.figure(figsize=(10, 6))
sns.histplot(freight_filtered, bins=50, kde=True, color='orange') # kde=True adiciona uma linha de estimativa de densidade
plt.title('Distribuição do Valor do Frete (abaixo de R$ 200)')
plt.xlabel('Valor do Frete (R$)')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# #### 1.3.4. Gráficos de Dispersão: Investigando Relações
# - **Propósito:** Observar a relação e a correlação entre duas variáveis numéricas contínuas.
# - **Exemplo Olist:** O peso de um item afeta seu custo de frete?

# %%
# Amostrando os dados para evitar sobreposição excessiva de pontos (overplotting)
df_sample = df.sample(n=5000, random_state=42)

# Criando o gráfico de dispersão
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_sample, x='product_weight_g', y='freight_value', alpha=0.5)
plt.title('Relação entre Peso do Produto e Valor do Frete')
plt.xlabel('Peso do Produto (g)')
plt.ylabel('Valor do Frete (R$)')
plt.xlim(0, 20000) # Limitando o eixo x para melhor visualização
plt.show()

# %% [markdown]
# - **Boas Práticas:**
#   - Cuidado para não inferir **causalidade** a partir da **correlação**. Gráficos de dispersão identificam relações *potenciais* para investigação futura.
# - **Exercício:** Crie um gráfico de dispersão de `price` vs `freight_value`. Existe uma correlação mais forte aqui do que entre o peso e o valor do frete? Por que isso faria sentido do ponto de vista do negócio?

# %%
# Amostrando os dados para evitar sobreposição excessiva de pontos (overplotting)
df_sample = df.sample(n=5000, random_state=42)

# Criando o gráfico de dispersão
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_sample, x='price', y='freight_value', alpha=0.5, color='red')
plt.title('Relação entre Preço e Produto e Valor de Frete')
plt.xlabel('Preço (R$)')
plt.ylabel('Valor do Frete (R$)')
plt.ylim(0, 200)
plt.xlim(0, 1500) # Limitando o eixo x para melhor visualização
plt.show()

# %% [markdown]
# #### 1.3.5. Box Plots: Comparando Distribuições e Encontrando Outliers
# - **Propósito:** Visualizar o resumo de cinco números (mínimo, 1º quartil, mediana, 3º quartil, máximo). É poderoso para comparar distribuições entre categorias e identificar outliers.
# - **Exemplo Olist:** As notas de avaliação variam entre as categorias de produtos mais vendidas?

# %%
# Identificando as 5 categorias mais vendidas
top_5_categories = df['product_category_name_english'].value_counts().head(5).index

# Filtrando o DataFrame para incluir apenas essas categorias
df_top5 = df[df['product_category_name_english'].isin(top_5_categories)]

# Criando os box plots
plt.figure(figsize=(14, 8))
sns.boxplot(data=df_top5, x='review_score', y='product_category_name_english', palette='coolwarm')
plt.title('Distribuição das Notas de Avaliação para as 5 Categorias Mais Vendidas')
plt.xlabel('Nota de Avaliação (1-5)')
plt.ylabel('Categoria do Produto')
plt.show()
# Out:
# /tmp/ipython-input-3925003114.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_top5, x='review_score', y='product_category_name_english', palette='coolwarm')

# %% [markdown]
# - **Boas Práticas:**
#   - Saiba interpretar os componentes: a caixa é o intervalo interquartil (IQR), a linha no meio é a mediana, e os "bigodes" (whiskers) geralmente se estendem até $1.5 \times IQR$. Pontos além são outliers.
#   - A posição da mediana e o comprimento dos bigodes indicam a assimetria (skewness) da distribuição.
# - **Exercício:** Calcule o tempo de entrega real em dias (`order_delivered_customer_date` - `order_purchase_timestamp`). Crie box plots para comparar a distribuição do tempo de entrega entre as 5 categorias de produtos mais vendidas. Existem categorias entregues mais rápido que outras?

# %%
# Calculate actual delivery time
df['delivery_time'] = df['order_delivered_customer_date'] - df['order_purchase_timestamp']

# Convert delivery time to days (as float)
df['delivery_time_days'] = df['delivery_time'].dt.days

# Filter out rows where delivery time is missing or negative (undelivered orders or data issues)
df_delivered = df.dropna(subset=['delivery_time_days'])
df_delivered = df_delivered[df_delivered['delivery_time_days'] >= 0]

# Identifying the top 5 most sold categories again, as the filtered df might be slightly different
top_5_categories = df_delivered['product_category_name_english'].value_counts().head(5).index

# Filtering the DataFrame to include only these categories for delivered orders
df_top5_delivered = df_delivered[df_delivered['product_category_name_english'].isin(top_5_categories)]

# Creating the box plots for delivery time
plt.figure(figsize=(14, 8))
sns.boxplot(data=df_top5_delivered, x='delivery_time_days', y='product_category_name_english', palette='viridis')
plt.title('Distribuição do Tempo de Entrega para as 5 Categorias Mais Vendidas')
plt.xlabel('Tempo de Entrega (Dias)')
plt.ylabel('Categoria do Produto')
plt.show()
# Out:
# /tmp/ipython-input-4279692051.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_top5_delivered, x='delivery_time_days', y='product_category_name_english', palette='viridis')

# %% [markdown]
# # Parte 2: Domando os Dados da Web (Dados Semi-estruturados e Não Estruturados)

# %% [markdown]
# ### 2.1. Lidando com JSON - A Linguagem das APIs Web
#
# #### 2.1.1. O Desafio: Estruturas Aninhadas
# - **Contexto:** JSON é o padrão para APIs REST. Sua flexibilidade é ótima para aplicações, mas sua natureza aninhada (objetos dentro de objetos, listas) é incompatível com a estrutura tabular plana exigida por ferramentas de análise.
#
# #### 2.1.2. Exemplo Prático: Criando e Achatando um JSON
# - **Tarefa:** Simular uma resposta de API criando um JSON aninhado a partir do nosso DataFrame e depois "achatá-lo" para um formato tabular.

# %%
# Criando uma estrutura de dados aninhada simulando uma resposta de API
# Vamos pegar 2 pedidos como exemplo
sample_orders_json = df[df['order_id'].isin(df['order_id'].unique()[:2])].copy()

# Agrupando os itens de cada pedido em uma lista de dicionários
nested_json_list = (sample_orders_json.groupby(['order_id', 'customer_city'])
                   .apply(lambda x: x[['product_id', 'price', 'freight_value']].to_dict('records'))
                   .reset_index(name='items')
                   .to_dict('records'))

print("Estrutura JSON Aninhada (simulando resposta de API):")
print(json.dumps(nested_json_list, indent=2))
# Out:
# Estrutura JSON Aninhada (simulando resposta de API):
# [
#   {
#     "order_id": "53cdb2fc8bc7dce0b6741e2150273451",
#     "customer_city": "barreiras",
#     "items": [
#       {
#         "product_id": "595fac2a385ac33a80bd5114aec74eb8",
#         "price": 118.7,
#         "freight_value": 22.76
#       }
#     ]
#   },
#   {
#     "order_id": "e481f51cbdc54678b7cc49136f2d6af7",
#     "customer_city": "sao paulo",
#     "items": [
#       {
#         "product_id": "87285b34884572647811a353c7ac498a",
#         "price": 29.99,
#         "freight_value": 8.72
#       }
#     ]
#   }
# ]
# /tmp/ipython-input-1909562332.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x[['product_id', 'price', 'freight_value']].to_dict('records'))

# %% [markdown]
# #### 2.1.3. A Solução: `pandas.json_normalize`
# - **Ferramenta:** A função `pandas.json_normalize()` é a solução ideal para transformar estruturas aninhadas em tabelas planas.
# - **Analogia para Desenvolvedores (ETL):** O processo de "achatar" um JSON é um mini-pipeline de **ETL (Extração, Transformação, Carga)**.
#   - **Extração:** Obter os dados da API (o que já fazemos).
#   - **Transformação:** Usar `json_normalize` para reestruturar os dados.
#   - **Carga:** Carregar o resultado em um DataFrame para análise.
# Isso conecta uma atividade familiar de desenvolvimento a um conceito central de engenharia de dados.

# %%
# Usando json_normalize para achatar a estrutura
df_flat = pd.json_normalize(
    data=nested_json_list, # A lista de dicionários que criamos
    record_path=['items'],  # A chave que contém a lista a ser "explodida" em novas linhas
    meta=['order_id', 'customer_city']  # Chaves do nível superior a serem repetidas para cada item
)

print("\nDataFrame Achatado:")
display(df_flat)
# Out:
# DataFrame Achatado:
#                          product_id   price  freight_value  \
# 0  595fac2a385ac33a80bd5114aec74eb8  118.70          22.76
# 1  87285b34884572647811a353c7ac498a   29.99           8.72
#
#                            order_id customer_city
# 0  53cdb2fc8bc7dce0b6741e2150273451     barreiras
# 1  e481f51cbdc54678b7cc49136f2d6af7     sao paulo

# %% [markdown]
# #### 2.1.4. Exercício
# - **Tarefa:** Crie uma estrutura JSON aninhada onde cada entrada representa uma `product_category_name_english` e contém uma lista aninhada de todas as avaliações para essa categoria (incluindo `review_score` e `review_comment_message`). Em seguida, use `json_normalize` para achatar essa estrutura de volta a um DataFrame onde cada linha é uma única avaliação, mas também contém o nome da categoria.

# %% [markdown]
# ### 2.2. Introdução à Análise de Texto (Processamento de Linguagem Natural - PLN)
#
# - **Contexto:** Chegamos aos dados não estruturados. A coluna `review_comment_message` é um exemplo perfeito: texto em português, com gírias, erros de digitação e sem formatação.
# - **Objetivo do PLN Básico:** Converter texto desordenado em um formato estruturado que possa ser contado, medido e analisado.
#
# #### 2.2.1. Primeiro Passo: Tokenização (Quebrando o Texto em Palavras)
# - **Conceito:** É o processo de dividir um texto em uma lista de seus componentes, ou "tokens" — geralmente palavras e pontuação.
# - **Biblioteca:** NLTK (Natural Language Toolkit), padrão para PLN em Python.

# %%
# Pegando um comentário de exemplo
sample_review = df['review_comment_message'].dropna().iloc[0]
print(f"Comentário Original: {sample_review}")

# Tokenizando o comentário
#nltk.download('punkt')
#nltk.download('punkt_tab')
tokens = word_tokenize(sample_review, language='portuguese')
print(f"\nTokens: {tokens}")
# Out:
# Comentário Original: Não testei o produto ainda, mas ele veio correto e em boas condições. Apenas a caixa que veio bem amassada e danificada, o que ficará chato, pois se trata de um presente.
#
# Tokens: ['Não', 'testei', 'o', 'produto', 'ainda', ',', 'mas', 'ele', 'veio', 'correto', 'e', 'em', 'boas', 'condições', '.', 'Apenas', 'a', 'caixa', 'que', 'veio', 'bem', 'amassada', 'e', 'danificada', ',', 'o', 'que', 'ficará', 'chato', ',', 'pois', 'se', 'trata', 'de', 'um', 'presente', '.']

# %% [markdown]
# #### 2.2.2. Segundo Passo: Limpando o Ruído (Removendo Stop Words)
# - **Conceito:** *Stop words* são palavras comuns e de baixa informação (`o`, `a`, `de`, `que`, `e`) que são removidas para focar a análise nas palavras mais significativas.
# - **Analogia para Desenvolvedores:** A remoção de *stop words* é uma forma de **redução de dimensionalidade** para texto. É o equivalente a filtrar logs para ver apenas `ERROR` ou usar `WHERE` em SQL para remover linhas irrelevantes. Estamos filtrando o "ruído" para focar no "sinal".

# %%
# Carregando stop words em português
stop_words = set(stopwords.words('portuguese'))

# Filtrando os tokens (removendo stop words e mantendo apenas palavras alfabéticas)
filtered_tokens = [word.lower() for word in tokens if word.lower() not in stop_words and word.isalpha()]
print(f"\nTokens Filtrados (sem stop words e pontuação): {filtered_tokens}")
# Out:
# Tokens Filtrados (sem stop words e pontuação): ['mini', 'cajon', 'shaker', 'chocalho', 'imita', 'cajon', 'péssimo']

# %% [markdown]
# #### 2.2.3. Exercício Final (Juntando Tudo)
# - **Tarefa:**
#   1. Selecione todas as avaliações com nota 1 (`review_score == 1`) que tenham uma mensagem de comentário.
#   2. Escreva um script que itere sobre cada uma dessas avaliações negativas.
#   3. Para cada avaliação, realize a tokenização e a remoção de *stop words* e pontuação.
#   4. Agregue todas as palavras restantes em uma única lista.
#   5. Use `collections.Counter` para encontrar as 20 palavras mais comuns em avaliações negativas.
# - **Objetivo:** Partir de texto bruto e não estruturado para chegar a um insight de negócio concreto e acionável. Que problemas essas palavras sugerem (ex: "demorou", "errado", "problema", "entrega")?

# %%
# Criando uma estrutura de dados aninhada para avaliações por categoria
# Vamos pegar algumas categorias como exemplo
sample_categories = ['health_beauty', 'computers_accessories', 'bed_bath_table']
reviews_by_category = df[df['product_category_name_english'].isin(sample_categories)].copy()

# Agrupando as avaliações de cada categoria em uma lista de dicionários
nested_reviews_list = (reviews_by_category.groupby('product_category_name_english')
                       .apply(lambda x: x[['review_score', 'review_comment_message']].to_dict('records'))
                       .reset_index(name='reviews')
                       .to_dict('records'))

print("Estrutura JSON Aninhada (avaliações por categoria):")
print(json.dumps(nested_reviews_list, indent=2))

# Usando json_normalize para achatar a estrutura
df_reviews_flat = pd.json_normalize(
    data=nested_reviews_list,  # A lista de dicionários agrupada por categoria
    record_path=['reviews'],  # A chave que contém a lista de avaliações a ser "explodida"
    meta=['product_category_name_english']  # Chave do nível superior a ser repetida para cada avaliação
)

print("\nDataFrame Achatado (avaliações com categoria):")
display(df_reviews_flat.head())
# Out:
# /tmp/ipython-input-1409613512.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x[['review_score', 'review_comment_message']].to_dict('records'))
# A saída de streaming foi truncada nas últimas 5000 linhas.
#         "review_score": 1,
#         "review_comment_message": "N\u00c3O RECEBI e NINGUEM da LOJA ME CONTATOU POR E-MAIL como prometido"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Produto muito excelente!! Entrega antes do prazo! Tudo dentro do combinado."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Chegou antes do dia previsto. Chegou tudo certo."
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Excelente compra entregue r\u00e1pido e toda descri\u00e7\u00e3o confer como nas fotos. \r\nRecomendo "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Progressiva realmente maravilhosa, sem cheiro ruim e deixa o cabelo muito hidratado e brilhante!"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Super r\u00e1pido "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Enrrega no prazo determinado"
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "\u00d3timo ,chegou ante do praso"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "\u00d3timo ,chegou ante do praso"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "N\u00e3o foi faturada, quando comprei mostrou que tinha em estoque, fiquei sem o produto, n\u00e3o \u00e9 um bom parceiro para as lannister"
#       },
#       {
#         "review_score": 2,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "recebi o produto bem antes do prazo"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Chegou super r\u00e1pido. Comprei 4 produtos. O que n\u00e3o entendi \u00e9 que cada um veio em uma caixa separado. Poderia ser na mesma. Achei desperd\u00edcio. O mesmo produto e embalados separados."
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Chegou super r\u00e1pido. Comprei 4 produtos. O que n\u00e3o entendi \u00e9 que cada um veio em uma caixa separado. Poderia ser na mesma. Achei desperd\u00edcio. O mesmo produto e embalados separados."
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Chegou super r\u00e1pido. Comprei 4 produtos. O que n\u00e3o entendi \u00e9 que cada um veio em uma caixa separado. Poderia ser na mesma. Achei desperd\u00edcio. O mesmo produto e embalados separados."
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Chegou super r\u00e1pido. Comprei 4 produtos. O que n\u00e3o entendi \u00e9 que cada um veio em uma caixa separado. Poderia ser na mesma. Achei desperd\u00edcio. O mesmo produto e embalados separados."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "excelente"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "sempre compro nas lojas lannister e sempre muito bem atendida com os meus produtos entregue em dia"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Gosto mto de comprar com vcs. "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": "O produto chegou com a caixa ama\u00e7ada... Como se tivessem colocado algo em cima dela. No entanto, sem avarias, mas neglig\u00eancia com o produto."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Veio tudo certinho\r\nMuito satisfeita com o produto"
#       },
#       {
#         "review_score": 2,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Entrega uma dia antes do previsto"
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Muito bom"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Vendedor \u00f3timo em honestidade e dignidade, atendimento impec\u00e1vel, voltarei a comprar grato."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Produto chegou no prazo certo."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Tudo entregue bem antes do prazo. SEM problemas!"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 2,
#         "review_comment_message": "N\u00e3o recebi o produto"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Foi entregue antes do prazo \r\nTudo ok, excelente !!"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "muito bom e chegou antes do prazo"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Eu fiz um pedido de dois itens, 1 shampoo da L?Or\u00e9al e um Condicionador Joico, s\u00f3 recebi o condicionador. Quando receberei o shampoo? Obrigada! Adriana "
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Os correios informou ontem dia 25 que o produto estava a cinco dias esperando retirada e foi devolvido dia 24/10 mas s\u00f3 recebi essa informa\u00e7\u00e3o ontem"
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "N\u00e3o gostei apenas por que a entrega \u00e9 feita pelos correios. "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "N\u00e3o recebi o produto e estou sem informa\u00e7\u00f5es. "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Produto muito bom , recebi bem antes do prazo , gostei muito e recomendo."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Os correios t\u00e1 uma bosta mesmo. O vendedor n\u00e3o deve ter culpa."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Produto n\u00e3o entregue no prazo fiz v\u00e1rias reclama\u00e7\u00f5es inclusive no reclama Aki mesmo assim veio faltando dois produtos s\u00f3 recebi ativador de cachos falaram que ainda entregaria essa semana vou aguarda"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": "Recebi o produto com nota fiscal diversa daquele que comprei"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": "Recomendo"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": "Eu havia pedido o cancelamento,no entanto o pedido foi entregue assim mesmo!"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "entregou ate antes do prazo"
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Produto conforme anunciado!!!"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "VEIO COM LACRE DA CAIXA RASGADO , MAIS ESTAVA TUDO CERTO."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Produto foi entregue no dia 03.03. e estarei testando a eficiencia do mesmo. Espero que realmente produza o efeito esperado."
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Meu produto n chegou entao n vou falar nada"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "sempre compro no stark e nunca me arrependo. entrega no prazo e produtos maravilhosos."
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "A empresa deveria testar produto antes "
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "quero receber o dinheiro da devolu\u00e7\u00e3o das venezianas que comprei da mazon"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "O meu produto veio falsificado . o passo 2 da progressiva veio quebrado . "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "\u00f2timo!"
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": "Gostei da entrega no prazo"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "entregue no prazo"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Comprei a arma\u00e7\u00e3o como sendo um modelo original, ou seja, da marca targaryen. Mas, na verdade \u00e9 uma r\u00e9plica da Dior. Queria adquirir um produto \"sem marca\". E n\u00e3o uma r\u00e9plica.\r\n"
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "GOSTEI "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "- mp3 player ok (entregue)\r\n- blend barba de respeito (N\u00e3o foi entregue)"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "sim eu recomendo esta loja,"
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Quero meu dinheiro de volta "
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Muito bom, e chegou antes do prazo"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Bom produto"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": "Boa Tarde . Comprei uma M\u00e1quina de cortar cabelo com SEIS pentes, recebi uma m\u00e1quina com QUATRO pentes. O atendimento foi r\u00e1pido. Entrega ANTECIPADA. Apenas uma falha, eu espero. "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Produto chegou bem embalado e antes do prazo final de entrega. Recomendo!"
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Nao indicaria pq o produto chegou em 1 dia e me cobraram frete de 12 reais falando que levaria ate 11 dias p/chegar.Acredito q foi enviado por sedex 10.Eu queria ter esperado mais e nao ter pago frete"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Estou satisfeita \r\n"
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Envie v\u00e1rios email para avisa sobre o atraso e at\u00e9 agora n\u00e3o recebi resposta. Espero que devolva o dinheiro. "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Muito boa, chegou antes do previsto,superou minha expectativa. Muito obrigada ."
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Estou mais que impressionado com a rapidez da entrega. S\u00f3 acho que poderia melhorar na embalagem, as canetas chegaram soltas dentro da caixa, o que pode ser preocupante. "
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Satisfeita cm a entrega"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Entrega r\u00e1pida , produto de qualidade!"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "quero meu produto"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "O prazo para entrega era de 14 dias \u00fateis, chegou em 2 dias! Muito bom! "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Excelente produto, recomendo."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "O produto chegou antes do prazo, chegou em perfeito estado parabens lannister continuem assim"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Fui muito bem atendida."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu estou tentando cancelar faz tempo devido o valor do frete muito abusivo "
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Recebi o produto em ordem. Antes do prazo estipulado. Em 48hs. Muito bom. Recomendo a todos."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "chegou antes do prazo!!!"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Ao expressar minha opini\u00e3o, deixo claro que a satisfa\u00e7\u00e3o do produto recebido em tempo acordado e em boas condi\u00e7\u00f5es \u00e9 o que se espera de uma empresa conceituada como a lannister. Parab\u00e9ns lannister!"
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "N\u00e3o testei o produto ainda, mas \u00e9 bem consistente. Tamb\u00e9m \u00e9 muito pequeno "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "A cinta t\u00e9rmica quando ligou na tomada come\u00e7ou a derreter e come\u00e7ou a queimar a pessoa que usou "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "En omenda entregue bem antes do prazo. Recomendo compras na anericanas.com"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "O produto chegou r\u00e1pido e perfeito. Super indico."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "O produto chegou r\u00e1pido e perfeito. Super indico."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "recebi no prazo, loja confi\u00e1vel, os produtos que comprei s\u00e3o maravilhosos, amei minha compra."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "recebi no prazo, loja confi\u00e1vel, os produtos que comprei s\u00e3o maravilhosos, amei minha compra."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Pessima loja. Vendem recebem e n\u00e3o entregam. "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": "Ja comprei outras vezes mas estou tendo problemas nessa compra"
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "s\u00f3 levei um susto com o prazo inicial de mais de 15 dias, mas chegou em bem menos tempo!"
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "embora o prazo seja de 14 dias \u00fateis, o produto comprado no dia 09/05 s\u00f3 veio chegar no dia 2/6 e alem de chegar super atrasado ainda veio o produto errado."
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "A entrega foi feita no prazo"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Recebi certinho"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "produto bom e com bom pre\u00e7o"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "O produto foi entregue antes do prazo,e de \u00f3tima qualidade!!"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": "Recebi o produto danificado\r\n"
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Produto de acordo com an\u00fancio, muito bom. "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Compra feita com sucesso!\r\nEstou satisfeita, recebi o produto muito antes do previsto e foi exatamente o que estava no an\u00fancio. Parab\u00e9ns!\r\nAt\u00e9 a pr\u00f3xima compra. "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Atendido"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "As tesouras vieram tortas, cor diferente da divulgada na compra. "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Excelente servico"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Produto entregue conforme pedido. Muito boa a compra."
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": "Infelizmente o produto veio com defeito de f\u00e1brica e j\u00e1 acionei a devolu\u00e7\u00e3o do produto"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Fixa\u00e7\u00e3o excelente para qualquer tipo de cabelo!!!"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Entrega no prazo , recomendo a loja "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Entregue antes do prazo prometido, pre\u00e7o bom.\r\nAgora \u00e9 utilizar o produto."
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Entregue antes do prazo prometido, pre\u00e7o bom.\r\nAgora \u00e9 utilizar o produto."
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Entregue antes do prazo prometido, pre\u00e7o bom.\r\nAgora \u00e9 utilizar o produto."
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Entregue antes do prazo prometido, pre\u00e7o bom.\r\nAgora \u00e9 utilizar o produto."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Muito bom...chegou antes do previsto! "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Eu havia feito um comunicado q n\u00e3o tinha recebido mas houve um mal entendido .\r\nCorreu tudo bem\r\nObrigada"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Recomendo este vendedor. Rapido e otima embalagem"
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "O produto \u00e9 bom, mas a lannister deve estar fazendo uma promo\u00e7\u00e3o \u00e0s avessas, pois paguei 2 mas recebi s\u00f3 1, j\u00e1 fiz a reclama\u00e7\u00e3o no site mas at\u00e9 agora nada!"
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "O produto \u00e9 bom, mas a lannister deve estar fazendo uma promo\u00e7\u00e3o \u00e0s avessas, pois paguei 2 mas recebi s\u00f3 1, j\u00e1 fiz a reclama\u00e7\u00e3o no site mas at\u00e9 agora nada!"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Super recomendo"
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Bom vendedor"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Pedi para que trocassem o produto por causa da voltagem e ainda n\u00e3o ganhei retorno "
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "recebi o produto corretamente \r\nObrigada "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "ENTREGA EFETUADA BEM ANTES DO PRAZO INFORMADO. PARAB\u00c9NS PELO ATENDIMENTO E OBRIGADA!"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "O produto nao foi entregue."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Tudo certo "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Tudo certo "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Tudo certo "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Tudo certo "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Recomendo"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Veio separados ,mas tudo OK,estou satisfeita"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "apesar da confus\u00e3o com a entrega, produto foi entregue. Agrade\u00e7o"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "gostei chegou certo."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Al\u00e9m de demorar, n\u00e3o chegou."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "A mesma \u00e9 um pouco pesada, mais tranquila para trabalhar "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "produto entregue antes do prazo!!!"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Comprei Escova De Dentes Curaprox Black Edition - Cerdas Pretas. Foi entregue Escova Roxa com cerdas Verdes. \r\nNada a ver. E a targaryen, parceira das lannister disse que n\u00e3o pode fazer nada. CORRAM."
#       },
#       {
#         "review_score": 2,
#         "review_comment_message": "Produto estava em falta no estoque e a empresa n\u00e3o checou."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "O ar que sai da escova n\u00e3o \u00e9 muito forte igual ao secador, mas ela cumpre bem o seu papel, alisa e seca o cabelo. "
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": "Bom"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "O produto \u00e9 exatamente como o apresentado. Pelo pre\u00e7o, \u00e9 o melhor custo/benef\u00edcio. Sem conta a entrega, que foi uma das mais r\u00e1pidas que j\u00e1 tive na internet."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "produto de qualidade"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "At\u00e9 agora n\u00e3o recebi"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Creme maravilhoso para dor nas pernas. Recomendo."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "O produto estava de acordo com o an\u00fancio."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Produto de Boa Qualidade."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "produto de \u00f3tima qualidade, acompanhado por um estojo lindo, recomendo."
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Solicito o estorno do pagamento no cart\u00e3o de cr\u00e9dito,pela falta de entrega do produto."
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "chegou direitinho"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Produto top"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "MTA BOA A EFICI\u00caNCIA DE VCS !"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": "boa qualidade e confort\u00e1vel"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Dwmorou demais e ficou tendo problemas fiz outras compras no mesmo dia e chegou rapido\r\n"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Muito bom amei o produto"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Log\u00edstica excelente"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "que esta agilidade e qualidade de servi\u00e7o seja ininterrupta."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
# ...
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Excelente compra"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Otimo"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "\u00d3timo produto...e stark sempre atendendo da melhor forma!!!"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "o produto ainda n\u00e3o chegou apenas a nota fiscal"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Gosrei da pontualidade e gosto muito do cuidado \r\nQue a lojas lannister tem com os seus clientes . Obrigada pela aten\u00e7\u00e3o."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "\u00d3timo produto, chegou super r\u00e1pido em casa e al\u00e9m disso a qualidade do material \u00e9 boa. Gostei bastante e agora vou usa-la no dia a dia. "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Ainda nao recebi o produto"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Tudo certo!"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Quanto ao atendimento, a lannister est\u00e1 de parab\u00e9ns. Al\u00e9m de entregarem sempre dentromdo prazo."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Td certo! Apesar dos problemas dos correios..."
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": "N\u00e3o serviu, ficou pequena, solicitei devolu\u00e7\u00e3o."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Maravilhoso! Faz um pouquinho de barulho mas faz bastante fuma\u00e7a!"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "AL\u00c9M DE RECEBER O PRODUTO ERRADO,VEIO DENTRO DA CX UMA CARTA DE UMA OUTRA CLIENTE INSATISFEITA POR TB TER RECEBIDO O PRODUTO ERRADO,CANCELEI MINHA COMPRA DEPOIS DESSE OCORRIDO DEU PVER A CREDIBILIDADE"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "\u00d3tima loja"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Chegou bem antes do esperado \ud83d\ude0d"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Sempre compro e vou continuar comprando , chega sempre antes do prazo e em perfeito estado ."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Entrega r\u00e1pida, produto perfeito."
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Muito satisfeita com a minha compra !!!"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Recomendo o vendedor.."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Excelente produto "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Ok"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "N\u00e3o comprem nesse site"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Ainda n\u00e3o utilizei o produto ent\u00e3o n\u00e3o posso opinar sobre o mesmo. Contudo recomendo a loja, recebi o produto de forma extremamente r\u00e1pida."
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Gostei do produto, de acordo com o que eu esperava, muito bom, o prazo de entrega nem se fala, dentro do tempo. "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Est\u00e3o de Parab\u00e9ns, chegou antes do previsto "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "O produto chegou bem antes da data prevista."
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Tem mais de um m\u00eas que comprei o produto e ainda n\u00e3o recebi. A gente paga na hora mas ningu\u00e9m da nem satisfa\u00e7\u00e3o quanto a entrega. Muita falta de respeito. "
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Entregou no prazo."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Gostei bastante do prazo, foi entregue antes do previsto."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "O produto chegou no prazo, mas recusei no ato da entrega por motivos de desist\u00eancia."
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "N\u00c3O RECEBI MEU PRODUTO E AINDA COLOCARAM QUE FOI ENTREGUE. ISSO \u00c9 UMA FALTA DE RESPEITO MUITO GRANDE, QUERO MEU DINHEIRO DE VOLTA."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "N\u00e3o entrega os produtos pelo correios"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Cancelei o pedido ! Pesso que me envie outro boleto."
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "valor acess\u00edvel.... "
#       },
#       {
#         "review_score": 2,
#         "review_comment_message": "Ainda estou aguardando a entrega"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": "CONSIDERANDO O VALOR DA COMPRA, O FRETE DEVERIA SER GRATUITO."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Entrega r\u00e1pida e produto chegou de acordo."
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Amei o produto,amei comprar nesse site. F\u00e1cil de fazer a compra e chegou no prazo,melhor ainda bem antes do prazo..parabens comprarei mais nesse site..ah o pre\u00e7o tbm estava \u00f3timo "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Muito bom"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Loja excelente. Cumpre o que anuncia e a promessa contida no an\u00fancio."
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": "Produto novo, parece estar tudo certo, por\u00e9m a caixa nao veio lacrada. "
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 2,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 2,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 2,
#         "review_comment_message": "Esse produto veio certo ,mas j\u00e1 fiz compra anterior que tive que cancelar o pedido pois j\u00e1 estava com atraso de um m\u00eas na entrega.\r\n"
#       },
#       {
#         "review_score": 3,
#         "review_comment_message": "Gostaria de trocar o produto, pois o mesmo foi entregue avariado"
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Ainda n\u00e3o chegou, e n\u00e3o consigo rastrear o produto, preciso do c\u00f3digo de rastreamento!"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": "Top "
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Eu tive que retirar no correio, sendo que paguei o frete. \u00c9 a segunda encomenda que tenho que retirar nos correios, estou cancelando minha conta."
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Veio td certo chegou mt antes do prazo,perfeito,com certeza comprarei novamente"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Veio td certo chegou mt antes do prazo,perfeito,com certeza comprarei novamente"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 1,
#         "review_comment_message": "Nao volto a comprar com esta loja , demorando uma vida a enttega deste produto"
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": "Satisfa\u00e7\u00e3o garantida"
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 4,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       },
#       {
#         "review_score": 5,
#         "review_comment_message": NaN
#       }
#     ]
#   }
# ]
#
# DataFrame Achatado (avaliações com categoria):
#    review_score review_comment_message product_category_name_english
# 0             5                    NaN                bed_bath_table
# 1             5                    NaN                bed_bath_table
# 2             3                    NaN                bed_bath_table
# 3             4                    NaN                bed_bath_table
# 4             3                    NaN                bed_bath_table

# %% [markdown]
# # Conclusão
#
# Ao longo desta aula, realizamos uma transição fundamental: de desenvolvedores que consomem e apresentam dados para analistas que os interrogam e extraem valor deles.
#
# **O que conquistamos:**
# - **Visualização com Propósito:** Entendemos que visualizar dados é uma necessidade para evitar conclusões equivocadas (Quarteto de Anscombe) e que sua eficácia reside na otimização cognitiva (atributos pré-atentivos).
# - **Linguagem de Gráficos:** Desmistificamos a criação de visualizações com a Gramática dos Gráficos (dados, estética, geometria), um conceito análogo aos padrões de design de software.
# - **Kit de Ferramentas Prático:** Dominamos cinco tipos de gráficos essenciais para responder a uma vasta gama de perguntas de negócio.
# - **Domínio de Dados da Web:** Aprendemos a achatar o JSON aninhado de APIs, construindo uma ponte direta entre o desenvolvimento de aplicações e a ciência de dados.
# - **Análise de Texto Inicial:** Demos os primeiros passos no Processamento de Linguagem Natural, aprendendo a limpar texto para extrair as palavras que carregam o maior peso de significado.
#
# A jornada de um desenvolvedor para a ciência de dados é uma extensão natural de suas habilidades. As ferramentas e técnicas apresentadas aqui são o próximo passo, permitindo não apenas construir sistemas que *usam* dados, mas também gerar insights que *direcionam* o negócio.
